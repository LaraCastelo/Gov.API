# %%
import pandas as pd
import os
import matplotlib.pyplot as ply
# %matplotlib inline

# %%
from dotenv import load_dotenv
import os
load_dotenv()
os.environ["OPENROUTER_API_KEY_LEDE"][:8]

# %%
df_1 = pd.read_csv('202601_CPGF.csv', encoding="latin1", sep=";")
df_1
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 9674                  20000  Presidência da República         20101
# 9675                  20000  Presidência da República         20101
# 9676                  20000  Presidência da República         20101
# 9677                  20000  Presidência da República         20101
# 9678                  20000  Presidência da República         20101
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
data = pd.read_json('response_1784663652354.json', encoding="latin1")

# %%
import json

with open('response_1784664659228.json', encoding='latin1') as f:
    data = json.load(f)

df = pd.json_normalize(data)
df
# Out:
#            id mesExtrato dataTransacao valorTransacao  tipoCartao.id  \
# 0   474900093    07/2025    17/06/2025         447,93              1
# 1   474900157    07/2025    18/06/2025         235,50              1
# 2   474900221    07/2025    25/06/2025         510,00              1
# 3   474900285    07/2025    24/06/2025         686,00              1
# 4   474900349    07/2025    24/06/2025         425,00              1
# 5   474900413    07/2025    06/06/2025         940,00              1
# 6   474900477    07/2025    06/06/2025          80,00              1
# 7   474900541    07/2025    06/06/2025       1.600,00              1
# 8   474900605    07/2025    09/06/2025       2.370,00              1
# 9   474900669    07/2025    09/06/2025         290,22              1
# 10  474900733    07/2025    09/06/2025          43,43              1
# 11  474900797    07/2025    13/06/2025         316,41              1
# 12  474900861    07/2025    13/06/2025          67,56              1
# ...

# %%
#só retornou a primeira página
#então, vale a pena fazer o pedido no pelo python
#refazer o pedido
